# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.dpi']= 100
matplotlib.rcParams['figure.figsize'] = 20, 10
from statsmodels.tsa.seasonal import seasonal_decompose
# %matplotlib inline

# %%
data = pd.read_csv('bavl_data.csv')

# %%
data
# Out:
#      <TICKER> <PER>      <DATE>    <TIME>  <OPEN>  <HIGH>   <LOW>  <CLOSE>  \
# 0        BAVL     D  25.03.2009  10:00:00  0.0500  0.0500  0.0500   0.0500
# 1        BAVL     D  26.03.2009  10:00:00  0.0804  0.0816  0.0790   0.0810
# 2        BAVL     D  27.03.2009  10:00:00  0.0805  0.0805  0.0790   0.0790
# 3        BAVL     D  30.03.2009  10:00:00  0.0785  0.0785  0.0785   0.0785
# 4        BAVL     D  01.04.2009  10:00:00  0.0800  0.0810  0.0800   0.0810
# 5        BAVL     D  02.04.2009  10:00:00  0.0825  0.0865  0.0810   0.0865
# 6        BAVL     D  03.04.2009  10:00:00  0.0900  0.1130  0.0900   0.1030
# 7        BAVL     D  06.04.2009  10:00:00  0.1055  0.1280  0.1055   0.1250
# 8        BAVL     D  07.04.2009  10:00:00  0.1230  0.1230  0.1197   0.1199
# 9        BAVL     D  08.04.2009  10:00:00  0.1100  0.1185  0.1090   0.1180
# 10       BAVL     D  09.04.2009  10:00:00  0.1270  0.1330  0.1270   0.1320
# 11       BAVL     D  10.04.2009  10:00:00  0.1400  0.1400  0.1370   0.1375
# 12       BAVL     D  13.04.2009  10:00:00  0.1360  0.1410  0.1340   0.1380
# 13       BAVL     D  14.04.2009  10:00:00  0.1350  0.1425  0.1340   0.1370
# 14       BAVL     D  15.04.2009  10:00:00  0.1380  0.1385  0.1355   0.1380
# 15       BAVL     D  16.04.2009  10:00:00  0.1400  0.1510  0.1400   0.1510
# 16       BAVL     D  17.04.2009  10:00:00  0.1575  0.1650  0.1515   0.1570
# 17       BAVL     D  21.04.2009  10:00:00  0.1380  0.1485  0.1360   0.1395
# 18       BAVL     D  22.04.2009  10:00:00  0.1400  0.1470  0.1400   0.1435
# 19       BAVL     D  23.04.2009  10:00:00  0.1440  0.1550  0.1440   0.1530
# 20       BAVL     D  24.04.2009  10:00:00  0.1560  0.1560  0.1560   0.1560
# 21       BAVL     D  27.04.2009  10:00:00  0.1525  0.1600  0.1525   0.1600
# 22       BAVL     D  28.04.2009  10:00:00  0.1550  0.1550  0.1520   0.1525
# 23       BAVL     D  29.04.2009  10:00:00  0.1590  0.1655  0.1570   0.1655
# 24       BAVL     D  30.04.2009  10:00:00  0.1730  0.1740  0.1715   0.1720
# 25       BAVL     D  05.05.2009  10:00:00  0.1770  0.2000  0.1770   0.1900
# 26       BAVL     D  06.05.2009  10:00:00  0.1935  0.2070  0.1935   0.2070
# 27       BAVL     D  07.05.2009  10:00:00  0.2090  0.2750  0.2090   0.2700
# 28       BAVL     D  08.05.2009  10:00:00  0.2700  0.3150  0.2700   0.3150
# 29       BAVL     D  12.05.2009  10:00:00  0.3150  0.3710  0.3150   0.3710
# ...       ...   ...         ...       ...     ...     ...     ...      ...
# 2235     BAVL     D  03.05.2018  10:00:00  0.3601  0.3601  0.3500   0.3547
# 2236     BAVL     D  04.05.2018  10:00:00  0.3578  0.3590  0.3562   0.3586
# 2237     BAVL     D  07.05.2018  10:00:00  0.3582  0.3582  0.3530   0.3530
# 2238     BAVL     D  08.05.2018  10:00:00  0.3550  0.3600  0.3550   0.3575
# 2239     BAVL     D  10.05.2018  10:00:00  0.3588  0.3588  0.3550   0.3570
# 2240     BAVL     D  11.05.2018  10:00:00  0.3338  0.3577  0.3338   0.3550
# 2241     BAVL     D  14.05.2018  10:00:00  0.3640  0.3640  0.3549   0.3578
# 2242     BAVL     D  15.05.2018  10:00:00  0.3600  0.3600  0.3505   0.3546
# 2243     BAVL     D  16.05.2018  10:00:00  0.3500  0.3550  0.3400   0.3446
# 2244     BAVL     D  17.05.2018  10:00:00  0.3372  0.3483  0.3333   0.3387
# 2245     BAVL     D  18.05.2018  10:00:00  0.3410  0.3448  0.3372   0.3448
# 2246     BAVL     D  21.05.2018  10:00:00  0.3496  0.3496  0.3400   0.3462
# 2247     BAVL     D  22.05.2018  10:00:00  0.3462  0.3532  0.3407   0.3518
# 2248     BAVL     D  23.05.2018  10:00:00  0.3470  0.3513  0.3400   0.3513
# 2249     BAVL     D  24.05.2018  10:00:00  0.3575  0.3575  0.3140   0.3310
# 2250     BAVL     D  25.05.2018  10:00:00  0.3184  0.3280  0.3125   0.3224
# 2251     BAVL     D  29.05.2018  10:00:00  0.3336  0.3440  0.3336   0.3438
# 2252     BAVL     D  30.05.2018  10:00:00  0.3498  0.3499  0.3300   0.3300
# 2253     BAVL     D  31.05.2018  10:00:00  0.3252  0.3399  0.3252   0.3369
# 2254     BAVL     D  01.06.2018  10:00:00  0.3330  0.3394  0.3303   0.3365
# 2255     BAVL     D  04.06.2018  10:00:00  0.3399  0.3399  0.3399   0.3399
# 2256     BAVL     D  05.06.2018  10:00:00  0.3340  0.3398  0.3300   0.3378
# 2257     BAVL     D  06.06.2018  10:00:00  0.3398  0.3398  0.3398   0.3398
# 2258     BAVL     D  07.06.2018  10:00:00  0.3300  0.3365  0.3190   0.3364
# 2259     BAVL     D  08.06.2018  10:00:00  0.3348  0.3348  0.2910   0.3104
# 2260     BAVL     D  11.06.2018  10:00:00  0.3210  0.3210  0.3002   0.3093
# 2261     BAVL     D  12.06.2018  10:00:00  0.3118  0.3118  0.3030   0.3117
# 2262     BAVL     D  13.06.2018  10:00:00  0.3065  0.3087  0.2880   0.2880
# 2263     BAVL     D  14.06.2018  10:00:00  0.2998  0.3025  0.2870   0.2994
# 2264     BAVL     D  15.06.2018  10:00:00  0.2999  0.3189  0.2999   0.3189
#
#         <VOL>
# 0       40000
# 1     3870000
# 2     1070000
# 3      650000
# 4      790000
# 5     1570000
# 6     5140000
# 7     3790000
# 8     1240000
# 9     3150000
# 10    3380000
# 11    1000000
# 12    2390000
# 13    3570000
# 14     800000
# 15    1830000
# 16    4410000
# 17    4180000
# 18    5790000
# 19    3960000
# 20     410000
# 21    2060000
# 22    1150000
# 23    2170000
# 24     850000
# 25    2560000
# 26    1460000
# 27    3390000
# 28    1650000
# 29    1130000
# ...       ...
# 2235   420000
# 2236   120000
# 2237    20000
# 2238  1090000
# 2239   370000
# 2240  1090000
# 2241   180000
# 2242   740000
# 2243  1630000
# 2244   760000
# 2245   280000
# 2246   730000
# 2247  1070000
# 2248   480000
# 2249  1360000
# 2250   470000
# 2251   260000
# 2252   850000
# 2253   880000
# 2254   310000
# 2255    10000
# 2256   420000
# 2257    10000
# 2258   430000
# 2259  1160000
# 2260  1160000
# 2261   780000
# 2262  4000000
# 2263   690000
# 2264  1210000
#
# [2265 rows x 9 columns]

# %%
ts_data = data

# %%
ts_data['<DATE>'] = [pd.to_datetime(date, format='%dd%mm%yy', errors='ignore') for date in ts_data['<DATE>']]

# %%
[pd.to_datetime(date, format='%dd%mm%yy', errors='ignore') for date in ts_data['<DATE>']][:10]
# Out:
# ['25.03.2009',
#  '26.03.2009',
#  '27.03.2009',
#  '30.03.2009',
#  '01.04.2009',
#  '02.04.2009',
#  '03.04.2009',
#  '06.04.2009',
#  '07.04.2009',
#  '08.04.2009']

# %%
ts_data['<DATE>'] = pd.to_datetime(pd.Series(ts_data['<DATE>']), format="%d.%m.%Y")

# %%
ts_data.head()
# Out:
#   <TICKER> <PER>     <DATE>    <TIME>  <OPEN>  <HIGH>   <LOW>  <CLOSE>  \
# 0     BAVL     D 2009-03-25  10:00:00  0.0500  0.0500  0.0500   0.0500
# 1     BAVL     D 2009-03-26  10:00:00  0.0804  0.0816  0.0790   0.0810
# 2     BAVL     D 2009-03-27  10:00:00  0.0805  0.0805  0.0790   0.0790
# 3     BAVL     D 2009-03-30  10:00:00  0.0785  0.0785  0.0785   0.0785
# 4     BAVL     D 2009-04-01  10:00:00  0.0800  0.0810  0.0800   0.0810
#
#      <VOL>
# 0    40000
# 1  3870000
# 2  1070000
# 3   650000
# 4   790000

# %%
ts_data = ts_data.drop(columns=['<TICKER>', '<PER>', '<TIME>', '<LOW>', '<HIGH>', '<CLOSE>', '<VOL>'])

# %%
ts_data.head()
# Out:
#       <DATE>  <OPEN>
# 0 2009-03-25  0.0500
# 1 2009-03-26  0.0804
# 2 2009-03-27  0.0805
# 3 2009-03-30  0.0785
# 4 2009-04-01  0.0800

# %%
ts_data = pd.Series.from_csv('timeseries_data.csv')
# Out:
# /Users/tbatsenko/ml/lib/python3.7/site-packages/pandas/core/series.py:4141: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   infer_datetime_format=infer_datetime_format)

# %%
ts_data.head()
# Out:
# 2009-03-25    0.0500
# 2009-03-26    0.0804
# 2009-03-27    0.0805
# 2009-03-30    0.0785
# 2009-04-01    0.0800
# dtype: float64

# %%
ts_data.plot(figsize=(15, 5))

# %%
ts_data_ma = ts_data.rolling(20).mean()
ts_data_ma.plot(figsize=(15, 5))

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %% [markdown]
# ## Read news data

# %%
import pandas as pd
import os

# %%
titleFiles = [x for x in os.listdir("../scrapped-data-1560265947865/titles/") if x.endswith(".txt")]
textFiles = [x for x in os.listdir("../scrapped-data-1560265947865/texts/") if x.endswith(".txt")]

titles, texts = [], []
for title_file in titleFiles:
    with open("../scrapped-data-1560265947865/titles/" + title_file, encoding="utf-8") as f:
        titles.append(f.read())
for text_file in textFiles:
    with open("../scrapped-data-1560265947865/texts/" + text_file, encoding="utf-8") as f:
        texts.append(f.read())

news_title_data = pd.DataFrame({"date": titleFiles, "title": titles}) 
news_texts_data = pd.DataFrame({"date": textFiles, "text": texts})

# %%
news_title_data.head()
# Out:
#                             date  \
# 0  2009-08-10T17:30:01+03:00.txt
# 1  2016-09-29T17:40:00+03:00.txt
# 2  2017-08-19T20:00:00+03:00.txt
# 3  2014-06-05T09:19:46+03:00.txt
# 4  2016-06-03T20:48:00+03:00.txt
#
#                                                title
# 0  Инвесторы прогнозируют дальнейший рост украинс...
# 1  Стратегия на рынках капитала в ЦВЕ и других ре...
# 2  Главное за неделю: изменения в валютное законо...
# 3  Всеукраинская акция Райффайзен Банка Аваль «Ве...
# 4  Райффайзен Банк Аваль — снова среди самых наде...

# %%
news_texts_data.head()
# Out:
#                             date  \
# 0  2009-08-10T17:30:01+03:00.txt
# 1  2016-09-29T17:40:00+03:00.txt
# 2  2017-08-19T20:00:00+03:00.txt
# 3  2014-06-05T09:19:46+03:00.txt
# 4  2016-06-03T20:48:00+03:00.txt
#
#                                                 text
# 0  \nХотелось бы отметить один важный и необычный...
# 1  \nНовая норма. Сохранение низких процентных ст...
# 2  \nПрогноз на выходные. Куда катится наличный д...
# 3  \nОдесская областная дирекция Райффайзен Банка...
# 4  \nРайффайзен Банк Аваль снова занял ведущие по...

# %%
news_data = pd.merge(news_title_data, news_texts_data)

# %%
news_data.head()
# Out:
#                             date  \
# 0  2009-08-10T17:30:01+03:00.txt
# 1  2016-09-29T17:40:00+03:00.txt
# 2  2017-08-19T20:00:00+03:00.txt
# 3  2014-06-05T09:19:46+03:00.txt
# 4  2016-06-03T20:48:00+03:00.txt
#
#                                                title  \
# 0  Инвесторы прогнозируют дальнейший рост украинс...
# 1  Стратегия на рынках капитала в ЦВЕ и других ре...
# 2  Главное за неделю: изменения в валютное законо...
# 3  Всеукраинская акция Райффайзен Банка Аваль «Ве...
# 4  Райффайзен Банк Аваль — снова среди самых наде...
#
#                                                 text
# 0  \nХотелось бы отметить один важный и необычный...
# 1  \nНовая норма. Сохранение низких процентных ст...
# 2  \nПрогноз на выходные. Куда катится наличный д...
# 3  \nОдесская областная дирекция Райффайзен Банка...
# 4  \nРайффайзен Банк Аваль снова занял ведущие по...

# %%
date_ex = "2009-08-10T17:30:01+03:00.txt"
time_parsed = date_ex[:-10].split("T")[1]
date_parsed = date_ex[:-10].split("T")[0]
print(time_parsed, date_parsed)
# Out:
# 17:30:01 2009-08-10

# %%
news_data.describe()
# Out:
#                                  date  \
# count                            1572
# unique                           1572
# top     2013-08-09T20:50:01+03:00.txt
# freq                                1
#
#                                                     title  \
# count                                                1572
# unique                                               1554
# top     Новый рейтинг устойчивости банков от портала «...
# freq                                                    4
#
#                                                      text
# count                                                1572
# unique                                               1571
# top     \nак сообщалось ранее, с марта 2016 года в Рай...
# freq                                                    2

# %%
news_data["time"] = [date[:-10].split("T")[1] for date in news_data.date]
news_data["date"] = [date[:-10].split("T")[0] for date in news_data.date]

# %%
news_data.head()
# Out:
#          date                                              title  \
# 0  2009-08-10  Инвесторы прогнозируют дальнейший рост украинс...
# 1  2016-09-29  Стратегия на рынках капитала в ЦВЕ и других ре...
# 2  2017-08-19  Главное за неделю: изменения в валютное законо...
# 3  2014-06-05  Всеукраинская акция Райффайзен Банка Аваль «Ве...
# 4  2016-06-03  Райффайзен Банк Аваль — снова среди самых наде...
#
#                                                 text      time
# 0  \nХотелось бы отметить один важный и необычный...  17:30:01
# 1  \nНовая норма. Сохранение низких процентных ст...  17:40:00
# 2  \nПрогноз на выходные. Куда катится наличный д...  20:00:00
# 3  \nОдесская областная дирекция Райффайзен Банка...  09:19:46
# 4  \nРайффайзен Банк Аваль снова занял ведущие по...  20:48:00

# %%
news_data.head(20)
# Out:
#           date                                              title  \
# 0   2009-08-10  Инвесторы прогнозируют дальнейший рост украинс...
# 1   2016-09-29  Стратегия на рынках капитала в ЦВЕ и других ре...
# 2   2017-08-19  Главное за неделю: изменения в валютное законо...
# 3   2014-06-05  Всеукраинская акция Райффайзен Банка Аваль «Ве...
# 4   2016-06-03  Райффайзен Банк Аваль — снова среди самых наде...
# 5   2013-09-05  Индекс «Украинской биржи» UX завершил день неб...
# 6   2010-10-19      Суд закрыл дело о банкротстве «Хлеба Украины»
# 7   2017-06-02  Райффайзен Банк Интернациональ запускает финте...
# 8   2014-12-03  Что помогло одному из крупнейших банков страны...
# 9   2013-12-03  12 декабря в Киеве начинает работу XI Ежегодна...
# 10  2009-03-08  64% валюты, которую банки приобрели по льготно...
# 11  2010-04-20                 Крупнейшие кредиторы правительства
# 12  2011-08-18      Украинские фондовые биржи открылись снижением
# 13  2013-04-15  Индекс «Украинской биржи» завершил день снижен...
# 14  2017-07-11  Платите картой Mastercard от Райффайзен Банка ...
# 15  2016-01-11                          Банки сократили отделения
# 16  2018-04-05  Банки, які зможуть брати участь у валютних інт...
# 17  2019-01-15  Відтепер пенсіонери зможуть знімати кошти з бу...
# 18  2009-05-22               В какие банки возвращаются вкладчики
# 19  2017-11-21  Райффайзен Банк Аваль узяв участь у ярмарку ва...
#
#                                                  text      time
# 0   \nХотелось бы отметить один важный и необычный...  17:30:01
# 1   \nНовая норма. Сохранение низких процентных ст...  17:40:00
# 2   \nПрогноз на выходные. Куда катится наличный д...  20:00:00
# 3   \nОдесская областная дирекция Райффайзен Банка...  09:19:46
# 4   \nРайффайзен Банк Аваль снова занял ведущие по...  20:48:00
# 5   \nИндекс «Украинской биржи» UX завершил день с...  19:03:49
# 6   \nСегодня, 19 октября, стало известно, что Хоз...  12:17:27
# 7   \n1 июня 2017 года Йоганн Штробль, председател...  14:59:00
# 8   \nПосле продажи УкрСиббанка финансовой группе ...  12:02:00
# 9   \nЦелью Конференции является обсуждение актуал...  11:47:53
# 10  \n64,2% валюты или 22,154 млн долларов,\nкотор...  10:12:50
# 11  \nОколо половины облигаций госзайма, размещенн...  08:51:44
# 12  \nТорговые сессии на отечественном фондовом ры...  12:04:24
# 13  \nИндекс «Украинской биржи» завершил день сниж...  18:12:57
# 14  \nКлиенты Райффайзен Банка Аваль – вадельцы ка...  14:21:00
# 15  \nНациональный банк опубликовал данные по коли...  12:46:00
# 16  \nНаціональний банк затвердив перелік банків, ...  18:33:00
# 17  \nГарні новини для клієнтів банку, що користую...  17:20:00
# 18  \n\nДанные деятельности 8 крупнейших банков ст...  10:00:18
# 19  \nРайффайзен Банк Аваль взяв участь у XII Ярма...  17:20:00

# %%
import sys
# !{sys.executable} -m pip install tokenize_uk
# Out:
# Requirement already satisfied: tokenize_uk in /Users/tbatsenko/ml/lib/python3.7/site-packages (0.2.0)
# Requirement already satisfied: six in /Users/tbatsenko/ml/lib/python3.7/site-packages (from tokenize_uk) (1.12.0)

# %%
from langdetect import detect

news_data["lang"] = [detect(text) for text in news_data.text]

# %%
news_data.head(30)
# Out:
#           date                                              title  \
# 0   2009-08-10  Инвесторы прогнозируют дальнейший рост украинс...
# 1   2016-09-29  Стратегия на рынках капитала в ЦВЕ и других ре...
# 2   2017-08-19  Главное за неделю: изменения в валютное законо...
# 3   2014-06-05  Всеукраинская акция Райффайзен Банка Аваль «Ве...
# 4   2016-06-03  Райффайзен Банк Аваль — снова среди самых наде...
# 5   2013-09-05  Индекс «Украинской биржи» UX завершил день неб...
# 6   2010-10-19      Суд закрыл дело о банкротстве «Хлеба Украины»
# 7   2017-06-02  Райффайзен Банк Интернациональ запускает финте...
# 8   2014-12-03  Что помогло одному из крупнейших банков страны...
# 9   2013-12-03  12 декабря в Киеве начинает работу XI Ежегодна...
# 10  2009-03-08  64% валюты, которую банки приобрели по льготно...
# 11  2010-04-20                 Крупнейшие кредиторы правительства
# 12  2011-08-18      Украинские фондовые биржи открылись снижением
# 13  2013-04-15  Индекс «Украинской биржи» завершил день снижен...
# 14  2017-07-11  Платите картой Mastercard от Райффайзен Банка ...
# 15  2016-01-11                          Банки сократили отделения
# 16  2018-04-05  Банки, які зможуть брати участь у валютних інт...
# 17  2019-01-15  Відтепер пенсіонери зможуть знімати кошти з бу...
# 18  2009-05-22               В какие банки возвращаются вкладчики
# 19  2017-11-21  Райффайзен Банк Аваль узяв участь у ярмарку ва...
# 20  2017-11-06  Індивідуальні е-ліцензії на перерахування валю...
# 21  2014-12-12  Нацбанк пересмотрел список банков-дилеров на р...
# 22  2018-09-04  Райффайзен Банк Аваль підтримав видання інфогр...
# 23  2009-03-05   Вчера на валютном аукционе НБУ продал $61,03 млн
# 24  2017-03-24           В ожидании Трампа, МВФ и здравого смысла
# 25  2010-08-05      Кабмин толкает вверх доходность НДС-облигаций
# 26  2016-02-24                                     Маленький Фонд
# 27  2019-04-08  4-ий рік поспіль Райффайзен Банк Аваль очолює ...
# 28  2013-12-09  «Украинская биржа» закрылась понижением индекс...
# 29  2017-09-11  Преміум-центр нового формату відкрив Райффайзе...
#
#                                                  text      time lang
# 0   \nХотелось бы отметить один важный и необычный...  17:30:01   ru
# 1   \nНовая норма. Сохранение низких процентных ст...  17:40:00   ru
# 2   \nПрогноз на выходные. Куда катится наличный д...  20:00:00   ru
# 3   \nОдесская областная дирекция Райффайзен Банка...  09:19:46   ru
# 4   \nРайффайзен Банк Аваль снова занял ведущие по...  20:48:00   ru
# 5   \nИндекс «Украинской биржи» UX завершил день с...  19:03:49   ru
# 6   \nСегодня, 19 октября, стало известно, что Хоз...  12:17:27   ru
# 7   \n1 июня 2017 года Йоганн Штробль, председател...  14:59:00   ru
# 8   \nПосле продажи УкрСиббанка финансовой группе ...  12:02:00   ru
# 9   \nЦелью Конференции является обсуждение актуал...  11:47:53   ru
# 10  \n64,2% валюты или 22,154 млн долларов,\nкотор...  10:12:50   ru
# 11  \nОколо половины облигаций госзайма, размещенн...  08:51:44   ru
# 12  \nТорговые сессии на отечественном фондовом ры...  12:04:24   ru
# 13  \nИндекс «Украинской биржи» завершил день сниж...  18:12:57   ru
# 14  \nКлиенты Райффайзен Банка Аваль – вадельцы ка...  14:21:00   ru
# 15  \nНациональный банк опубликовал данные по коли...  12:46:00   ru
# 16  \nНаціональний банк затвердив перелік банків, ...  18:33:00   uk
# 17  \nГарні новини для клієнтів банку, що користую...  17:20:00   uk
# 18  \n\nДанные деятельности 8 крупнейших банков ст...  10:00:18   ru
# 19  \nРайффайзен Банк Аваль взяв участь у XII Ярма...  17:20:00   uk
# 20  \nРайффайзен Банк Аваль запровадив послугу офо...  16:30:00   uk
# 21  \nВ список вошли 20 финучреждений \n\n\nНацион...  14:53:51   ru
# 22  \nРайффайзен Банк Аваль виступив партнером про...  17:20:00   uk
# 23  \nВчера, 4 марта,\nНациональный банк Украины п...  07:51:59   ru
# 24  \nРынки испугались за судьбу Трампа. МВФ отлож...  14:29:00   ru
# 25  \nПод давлением МВФ правительство приняло реше...  09:08:56   ru
# 26  \nДва года и 65 млрд гривен. Такие ресурсы пон...  10:07:00   ru
# 27  \nРайффайзен Банк Аваль вже четвертий рік посп...  16:10:00   uk
# 28  \n«Украинская биржа» закрылась понижением инде...  17:59:26   ru
# 29  \nРайффайзен Банк Аваль відкрив Преміум-центр ...  17:30:00   uk

# %%
news_data.to_csv("news_data.csv", encoding='utf-8')

# %%
import pandas as pd
from tokenize_uk import tokenize_uk
import io
import numpy as np
import pickle
import torch
from torch.utils.data import Dataset, DataLoader
import random
random.seed(0)
torch.manual_seed(0)

# %%
#!/usr/bin/python
#
# This example shows how to use the MITIE Python API to perform named entity
# recognition and also how to run a binary relation detector on top of the
# named entity recognition outputs.
#
import sys, os
# Make sure you put the mitielib folder into the python search path.  There are
# a lot of ways to do this, here we do it programmatically with the following
# two statements:


from mitie import *
from collections import defaultdict


print("loading NER model...")
ner_uk = named_entity_extractor('Models/uk_model.dat')
print("\nTags output by this NER model:", ner_uk.get_possible_ner_tags())
# Out:
# loading NER model...
#
# Tags output by this NER model: ['LOC', 'ORG', 'PERS', 'MISC']

# %%
# Load a text file and convert it into a list of words.
tokens = tokenize(news_data.text[0].encode('utf-8'))
tokens = list(map(lambda x : x.decode('utf-8'), tokens))
print("Tokenized input:", tokens)

entities = ner_uk.extract_entities(tokens)
print("\nEntities found:", entities)
print("\nNumber of entities detected:", len(entities))
# Out:
# Tokenized input: ['Хотелось', 'бы', 'отметить', 'один', 'важный', 'и', 'необычный', 'момент', 'на', 'украинских', 'фондовых', 'площадках', '.', 'Рост', 'количества', 'совершенных', 'сделок', 'и', 'объема', 'торгов', 'растет', 'третью', 'неделю', 'подряд', '(', 'это', 'особенно', 'ярко', 'видно', 'на', '«Украинской', 'бирже»', ')', '.', 'Это', 'говорит', 'о', 'том', ',', 'что', 'подъем', 'основан', 'на', 'относительно', 'прочном', 'фундаменте', ',', 'при', 'этом', 'можно', 'заметить', ',', 'что', 'во', 'время', 'коррекции', 'рынков', 'активность', 'немного', 'снижается', '.', 'Это', 'в', 'свою', 'очередь', ',', 'свидетельствует', 'о', 'том', ',', 'что', 'в', 'большинстве', 'своем', 'инвесторы', 'прогнозируют', 'дальнейший', 'рост', 'котировок', 'акций', 'отечественных', 'предприятий', '.', 'Удачная', 'неделя', 'для', 'рынка', 'акций', 'Прошедшая', 'неделя', 'для', 'украинского', 'рынка', 'акций', 'оказалась', 'весьма', 'удачной', 'для', 'обладателей', 'длинных', 'позиций', '.', 'Индекс', '«Украинской', 'биржи»', 'вырос', 'на', '4,69%', '(', 'за', 'последние', 'четыре', 'недели', 'рост', 'составил', '23,85%', '!', ')', 'до', '1114,7', 'пунктов', ',', 'при', 'объеме', 'торгов', '94,3', 'млн', '.', 'грн', '.', '!', 'Индекс', 'ПФТС', 'прибавил', '3,83%', 'дойдя', 'до', 'отметки', '439,33', 'пункта', ',', 'сделки', 'с', 'акциями', 'совершены', 'но', 'общую', 'сумму', '39,6', 'млн', '.', 'грн', '.', 'Основными', 'причинами', 'роста', 'стали', ',', 'во-первых', ',', 'позитивная', 'внешняя', 'конъюнктура', ',', 'а', 'во-вторых', ',', 'хорошие', 'внутренние', 'новости', ',', 'в', 'частности', 'рост', 'промышленного', 'производства', 'в', 'Украине', 'в', 'июле', 'на', '3,2%', '.', 'Одним', 'из', 'основных', 'событий', 'на', 'рынке', 'стало', 'погашение', 'Украиной', 'еврооблигаций', 'на', 'общую', 'сумму', '512', 'млн', '.', 'долл', '.', 'Это', 'может', 'привести', 'к', 'повышению', 'международного', 'кредитного', 'рейтинга', 'Украины', ',', 'что', ',', 'безусловно', ',', 'позитивно', 'отразится', 'на', 'отечественных', 'фондовых', 'площадках', ',', 'и', 'привлечет', 'интерес', 'нерезидентов', 'к', 'отечественному', 'фондовому', 'рынку', '.', 'Кроме', 'того', ',', 'наша', 'страна', 'полностью', 'и', 'в', 'срок', '(', 'даже', 'немного', 'раньше', ')', 'рассчиталась', 'за', 'российский', 'импортный', 'газ', ',', 'закупленный', 'в', 'июле', 'в', 'размере', '605', 'млн', '.', 'долл', '.', 'Таким', 'образом', ',', 'вероятность', 'объявления', 'дефолта', 'Украиной', 'становится', 'все', 'более', 'призрачной', '.', 'Отечественные', 'металлурги', 'нарастили', 'выпуск', 'своей', 'продукции', 'в', 'среднем', 'на', '16%', 'в', 'июле', ',', 'при', 'этом', 'завод', '«Азовсталь»', '(', '+8,17%', ',', 'на', 'УБ', ')', 'увеличил', 'производство', 'стали', 'на', '19%', ',', 'Енакиевский', 'МЗ', '(', '+5,48%', ',', 'УБ', ')', '–', 'на', '66,7%', 'м/м', '(', 'из-за', 'резкого', 'сокращения', 'производства', 'в', 'июне', ')', ',', 'ММК', 'им', '.', 'Ильича', '(', '+8%', ',', 'УБ', ')', '–', 'на', '13%', '.', 'Производство', 'кокса', 'увеличилось', 'на', '11,4%', ',', 'на', 'что', 'рынок', 'отреагировал', 'ростом', 'котировок', 'Ясиновского', 'КХ', '(', '+4,72%', ',', 'УБ', ')', ',', 'однако', 'акции', 'Авдеевского', 'КХ', 'за', 'неделю', 'упали', 'на', '2%', '(', 'УБ', ')', 'из-за', 'решения', 'собрания', 'акционеров', '7', 'июля', 'не', 'выплачивать', 'дивиденды', 'по', 'итогам', '2008', 'года', '.', 'Добыча', 'ЖРС', 'выросла', 'на', '23,8%', ',', 'акции', 'Полтавского', 'ГОКа', 'выросли', 'на', '6,19%', '(', 'УБ', ')', '.', 'Трубные', 'предприятия', 'продолжают', 'увеличивать', 'производство', ':', 'Нижнеднепровский', 'ТЗ', '-', 'на', '45,6%', ',', 'Новомосковский', 'ТЗ', '-', 'на', '44,9%', ',', 'Харцызский', 'трубный', '-', 'на', '10,6%', '(', 'динамика', 'относительно', 'небольшая', ',', 'поскольку', 'ХТЗ', 'еще', 'в', 'прошлом', 'месяце', 'сильно', 'нарастил', 'выпуск', ')', '.', 'Госбюджет', 'в', 'июле', 'перевыполнен', 'на', '0,2%', ',', 'однако', ' ...
#
# Entities found: [(range(30, 31), 'LOC', 0.2345345805205717), (range(177, 178), 'LOC', 0.9384319814133725), (range(253, 254), 'PERS', 0.6453268980605407), (range(284, 285), 'PERS', 0.3579456164149471), (range(294, 295), 'LOC', 0.25006948692554787), (range(302, 306), 'LOC', 0.34289447638870874), (range(348, 351), 'LOC', 0.2859308455882833), (range(357, 359), 'LOC', 0.416679911874863), (range(388, 390), 'LOC', 0.4144539098367932), (range(409, 410), 'PERS', 0.41656983539544973), (range(447, 449), 'ORG', 0.4568066164315911), (range(449, 451), 'PERS', 0.9646239809429114), (range(488, 489), 'LOC', 0.6809804186950561), (range(524, 528), 'PERS', 0.4759066049340314), (range(572, 573), 'ORG', 0.31672885838675047), (range(677, 679), 'PERS', 0.8607478173615916), (range(710, 711), 'LOC', 1.5501579148146476), (range(791, 792), 'LOC', 1.5483376017475479), (range(793, 794), 'PERS', 0.3577250796219502), (range(807, 809), 'ORG', 0.27636904739758744), (range(895, 896), 'LOC', 1.0316844611757578)]
#
# Number of entities detected: 21

# %%
entities_news_data = news_data.copy()
entities_news_data['LOC'] = 0
entities_news_data['ORG'] = 0
entities_news_data['PERS'] = 0
entities_news_data.head()
# Out:
#          date                                              title  \
# 0  2009-08-10  Инвесторы прогнозируют дальнейший рост украинс...
# 1  2016-09-29  Стратегия на рынках капитала в ЦВЕ и других ре...
# 2  2017-08-19  Главное за неделю: изменения в валютное законо...
# 3  2014-06-05  Всеукраинская акция Райффайзен Банка Аваль «Ве...
# 4  2016-06-03  Райффайзен Банк Аваль — снова среди самых наде...
#
#                                                 text      time lang  LOC  ORG  \
# 0  \nХотелось бы отметить один важный и необычный...  17:30:01   ru    0    0
# 1  \nНовая норма. Сохранение низких процентных ст...  17:40:00   ru    0    0
# 2  \nПрогноз на выходные. Куда катится наличный д...  20:00:00   ru    0    0
# 3  \nОдесская областная дирекция Райффайзен Банка...  09:19:46   ru    0    0
# 4  \nРайффайзен Банк Аваль снова занял ведущие по...  20:48:00   ru    0    0
#
#    PERS
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0

# %%
for index, row in entities_news_data.iterrows():
    LOC = 0
    ORG = 0
    PERS = 0
    
    tokens = tokenize(row.text.encode('utf-8'))
    tokens = list(map(lambda x : x.decode('utf-8'), tokens))
    
    entities = ner_uk.extract_entities(tokens)
    
    for item in entities:
        if item[1] == 'LOC':
            LOC += 1
        elif item[1] == 'PERS':
            PERS += 1
        elif item[1] == 'ORG':
            ORG += 1

    entities_news_data.LOC[index] = LOC
    entities_news_data.ORG[index] = ORG
    entities_news_data.PERS[index] = PERS
# Out:
# /Users/tbatsenko/ml/lib/python3.7/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/tbatsenko/ml/lib/python3.7/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/tbatsenko/ml/lib/python3.7/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-173-359326c83464> in <module>
#      17             ORG += 1
#      18
# ---> 19     entities_news_data.LOC[index] = LOC
#      20     entities_news_data.ORG[index] = ORG
#      21     entities_news_data.PERS[index] = PERS
#
# ~/ml/lib/python3.7/site-packages/pandas/core/series.py in __setitem__(self, key, value)
#    1036
#    1037         # do the setitem
# -> 1038         cacher_needs_updating = self._check_is_chained_assignment_possible()
#    1039         setitem(key, value)
#    1040         if cacher_needs_updating:
#
# ~/ml/lib/python3.7/site-packages/pandas/core/generic.py in _check_is_chained_assignment_possible(self)
#    3197             if ref is not None and ref._is_mixed_type:
#    3198                 self._check_setitem_copy(stacklevel=4, t='referant',
# -> 3199                                          force=True)
#    3200             return True
#    3201         elif self._is_copy:
#
# ~/ml/lib/python3.7/site-packages/pandas/core/generic.py in _check_setitem_copy(self, stacklevel, t, force)
#    3243             # the copy weakref
#    3244             try:
# -> 3245                 gc.collect(2)
#    3246                 if not gc.get_referents(self._is_copy()):
#    3247                     self._is_copy = None
#
# KeyboardInterrupt:

# %%
entities_news_data.head()

# %%
entities_news_data.to_csv("entities_news_data.csv", encoding='utf-8')

# %%
ts_data.head()
# Out:
# 2009-03-25    0.0500
# 2009-03-26    0.0804
# 2009-03-27    0.0805
# 2009-03-30    0.0785
# 2009-04-01    0.0800
# dtype: float64

# %%
price_data = pd.read_csv("timeseries_data.csv")
# all_data = pd.merge(price_data, news_data)

# %%
import csv

tone_dict_uk = {}

with open('tone-dict-uk.tsv') as tsvfile:
  reader = csv.reader(tsvfile, delimiter='\t')
  for row in reader:
  
        tone_dict_uk[row[0]] = int(row[1])
    
tone_dict_ru = {}

with open('tone-dict-ru.csv') as csvfile:
  reader = csv.reader(csvfile)
  for row in reader:
        try:  
            tone_dict_ru[row[0]] = int(row[1])
        except: 
            pass

# %%
tone_dict_uk['мрія']
# Out:
# 1

# %%
tone_dict_ru['ужас']
# Out:
# -5

# %%
data = pd.read_csv("timeseries_data_df.csv")

# %%
news_data.loc[news_data.date == '2009-03-25']['text'].values[0][:15]
# Out:
# '\nПока даже заоб'

# %%
data['article'] = [news_data.loc[news_data.date == curr_date].text for curr_date in data.date]

# %%
data.head()
# Out:
#          date   price                                            article
# 0  2009-03-25  0.0500  304    \nПока даже заоблачные процентные ставк...
# 1  2009-03-26  0.0804  530     \nФонд гарантирования вкладов определи...
# 2  2009-03-27  0.0805  1514    \nФонд гарантирования вкладов определи...
# 3  2009-03-30  0.0785              Series([], Name: text, dtype: object)
# 4  2009-04-01  0.0800  324    \nНациональный банк Украины предоставил...

# %%
data.article = [article.values[0].lower() if article.values.any() else '' for article in data.article]
data.article = [' '.join(list(map(lambda x : x.decode('utf-8'), tokenize(article.encode('utf-8'))))) if article else '' for article in data.article]
data.head()
# Out:
#          date   price                                            article
# 0  2009-03-25  0.0500  пока даже заоблачные процентные ставки и лояль...
# 1  2009-03-26  0.0804  фонд гарантирования вкладов определил восемь б...
# 2  2009-03-27  0.0805  фонд гарантирования вкладов определил 8 банков...
# 3  2009-03-30  0.0785
# 4  2009-04-01  0.0800  национальный банк украины предоставил 1 млрд г...

# %%
def get_sentiment_score(text, lang):
    text_sentiment_sum = 0
    for word in text.split(' '):

        if lang == 'uk':
            try:
                text_sentiment_sum += int(tone_dict_uk[word])
            except:
                pass
        if lang == 'ru':
            try:
                text_sentiment_sum += int(tone_dict_ru[word])
            except:
                pass
                
    return text_sentiment_sum / len(text.split(' '))

# %%
data['lang'] = [news_data.loc[news_data.date == curr_date].lang for curr_date in data.date]
data.lang = [lang.values[0] if lang.values.any() else '-' for lang in data.lang]
data.head()
# Out:
#          date   price                                            article lang
# 0  2009-03-25  0.0500  пока даже заоблачные процентные ставки и лояль...   ru
# 1  2009-03-26  0.0804  фонд гарантирования вкладов определил восемь б...   ru
# 2  2009-03-27  0.0805  фонд гарантирования вкладов определил 8 банков...   ru
# 3  2009-03-30  0.0785                                                       -
# 4  2009-04-01  0.0800  национальный банк украины предоставил 1 млрд г...   ru

# %%
data['sentiment_score'] = [get_sentiment_score(row[1].article, row[1].lang) for row in data.iterrows()]

# %%
data.head()
# Out:
#          date   price                                            article lang  \
# 0  2009-03-25  0.0500  \nПока даже заоблачные процентные ставки и лоя...   ru
# 1  2009-03-26  0.0804  \nФонд гарантирования вкладов определил восемь...   ru
# 2  2009-03-27  0.0805  \nФонд гарантирования вкладов определил 8\nбан...   ru
# 3  2009-03-30  0.0785                                                       -
# 4  2009-04-01  0.0800  \nНациональный банк Украины предоставил 1 млрд...   ru
#
#    sentiment_score
# 0         0.003509
# 1         0.000000
# 2         0.000000
# 3         0.000000
# 4         0.000000

# %%
data[''] = entities_news_data

# %%
entities_news_data = pd.read_csv('entities_news_data.csv')
entities_news_data.head()
# Out:
#    Unnamed: 0        date                                              title  \
# 0           0  2009-08-10  Инвесторы прогнозируют дальнейший рост украинс...
# 1           1  2016-09-29  Стратегия на рынках капитала в ЦВЕ и других ре...
# 2           2  2017-08-19  Главное за неделю: изменения в валютное законо...
# 3           3  2014-06-05  Всеукраинская акция Райффайзен Банка Аваль «Ве...
# 4           4  2016-06-03  Райффайзен Банк Аваль — снова среди самых наде...
#
#                                                 text      time lang  LOC  ORG  \
# 0  \nХотелось бы отметить один важный и необычный...  17:30:01   ru   11    3
# 1  \nНовая норма. Сохранение низких процентных ст...  17:40:00   ru   15    2
# 2  \nПрогноз на выходные. Куда катится наличный д...  20:00:00   ru    8    8
# 3  \nОдесская областная дирекция Райффайзен Банка...  09:19:46   ru    0    1
# 4  \nРайффайзен Банк Аваль снова занял ведущие по...  20:48:00   ru    1    4
#
#    PERS
# 0     7
# 1    19
# 2    29
# 3     1
# 4     0

# %%
data['LOC'] = [entities_news_data.loc[entities_news_data.date == curr_date].LOC for curr_date in data.date]
data['LOC'] = [loc.values[0] if loc.values.any() else 0 for loc in data['LOC']]

data['ORG'] = [entities_news_data.loc[entities_news_data.date == curr_date].ORG for curr_date in data.date]
data['ORG'] = [org.values[0] if org.values.any() else 0 for org in data['ORG']]

data['PERS'] = [entities_news_data.loc[entities_news_data.date == curr_date].PERS for curr_date in data.date]
data['PERS'] = [pers.values[0] if  pers.values.any() else 0 for pers in data['PERS']]

# %%
data.head(20)
# Out:
#           date   price                                            article  \
# 0   2009-03-25  0.0500  пока даже заоблачные процентные ставки и лояль...
# 1   2009-03-26  0.0804  фонд гарантирования вкладов определил восемь б...
# 2   2009-03-27  0.0805  фонд гарантирования вкладов определил 8 банков...
# 3   2009-03-30  0.0785
# 4   2009-04-01  0.0800  национальный банк украины предоставил 1 млрд г...
# 5   2009-04-02  0.0825  если временной администрации , назначенной нбу...
# 6   2009-04-03  0.0900  международное рейтинговое агентство moody 's i...
# 7   2009-04-06  0.1055
# 8   2009-04-07  0.1230
# 9   2009-04-08  0.1100
# 10  2009-04-09  0.1270
# 11  2009-04-10  0.1400  на кредитном рынке наметилась весенняя оттепел...
# 12  2009-04-13  0.1360
# 13  2009-04-14  0.1350  с начала кризиса отечественная банковская сист...
# 14  2009-04-15  0.1380
# 15  2009-04-16  0.1400
# 16  2009-04-17  0.1575
# 17  2009-04-21  0.1380
# 18  2009-04-22  0.1400
# 19  2009-04-23  0.1440
#
#    lang  sentiment_score  LOC  ORG  PERS
# 0    ru        -0.002665    6    4    38
# 1    ru         0.000000    2    0     0
# 2    ru         0.000000    2    0     0
# 3     -         0.000000    0    0     0
# 4    ru         0.000000    2    0     5
# 5    ru         0.000000    4    1     3
# 6    ru         0.000000    3    1     3
# 7     -         0.000000    0    0     0
# 8     -         0.000000    0    0     0
# 9     -         0.000000    0    0     0
# 10    -         0.000000    0    0     0
# 11   ru         0.002116   10    2    22
# 12    -         0.000000    0    0     0
# 13   ru         0.002987    4    8    23
# 14    -         0.000000    0    0     0
# 15    -         0.000000    0    0     0
# 16    -         0.000000    0    0     0
# 17    -         0.000000    0    0     0
# 18    -         0.000000    0    0     0
# 19    -         0.000000    0    0     0

# %%
data.to_csv("ready_data.csv", encoding='utf-8')

# %%
full_data = data.copy()

# %%
full_data['day_before_LOC'] = [full_data['LOC'][i-1] if i > 0 else 0 for i, loc in enumerate(full_data['LOC'])]
full_data['2_day_before_LOC'] = [full_data['LOC'][i-2] if i > 1 else 0 for i, loc in enumerate(full_data['LOC'])]
full_data['3_day_before_LOC'] = [full_data['LOC'][i-3] if i > 2 else 0 for i, loc in enumerate(full_data['LOC'])]

# %%
full_data['day_before_ORG'] = [full_data['ORG'][i-1] if i > 0 else 0 for i, loc in enumerate(full_data['ORG'])]
full_data['2_day_before_ORG'] = [full_data['ORG'][i-2] if i > 1 else 0 for i, loc in enumerate(full_data['ORG'])]
full_data['3_day_before_ORG'] = [full_data['ORG'][i-3] if i > 2 else 0 for i, loc in enumerate(full_data['ORG'])]

# %%
full_data['day_before_PERS'] = [full_data['PERS'][i-1] if i > 0 else 0 for i, loc in enumerate(full_data['PERS'])]
full_data['2_day_before_PERS'] = [full_data['PERS'][i-2] if i > 1 else 0 for i, loc in enumerate(full_data['PERS'])]
full_data['3_day_before_PERS'] = [full_data['PERS'][i-3] if i > 2 else 0 for i, loc in enumerate(full_data['PERS'])]

# %%
full_data.head(20)
# Out:
#           date   price                                            article  \
# 0   2009-03-25  0.0500  пока даже заоблачные процентные ставки и лояль...
# 1   2009-03-26  0.0804  фонд гарантирования вкладов определил восемь б...
# 2   2009-03-27  0.0805  фонд гарантирования вкладов определил 8 банков...
# 3   2009-03-30  0.0785
# 4   2009-04-01  0.0800  национальный банк украины предоставил 1 млрд г...
# 5   2009-04-02  0.0825  если временной администрации , назначенной нбу...
# 6   2009-04-03  0.0900  международное рейтинговое агентство moody 's i...
# 7   2009-04-06  0.1055
# 8   2009-04-07  0.1230
# 9   2009-04-08  0.1100
# 10  2009-04-09  0.1270
# 11  2009-04-10  0.1400  на кредитном рынке наметилась весенняя оттепел...
# 12  2009-04-13  0.1360
# 13  2009-04-14  0.1350  с начала кризиса отечественная банковская сист...
# 14  2009-04-15  0.1380
# 15  2009-04-16  0.1400
# 16  2009-04-17  0.1575
# 17  2009-04-21  0.1380
# 18  2009-04-22  0.1400
# 19  2009-04-23  0.1440
#
#    lang  sentiment_score  LOC  ORG  PERS  day_before_LOC  2_day_before_LOC  \
# 0    ru        -0.002665    6    4    38               0                 0
# 1    ru         0.000000    2    0     0               6                 0
# 2    ru         0.000000    2    0     0               2                 6
# 3     -         0.000000    0    0     0               2                 2
# 4    ru         0.000000    2    0     5               0                 2
# 5    ru         0.000000    4    1     3               2                 0
# 6    ru         0.000000    3    1     3               4                 2
# 7     -         0.000000    0    0     0               3                 4
# 8     -         0.000000    0    0     0               0                 3
# 9     -         0.000000    0    0     0               0                 0
# 10    -         0.000000    0    0     0               0                 0
# 11   ru         0.002116   10    2    22               0                 0
# 12    -         0.000000    0    0     0              10                 0
# 13   ru         0.002987    4    8    23               0                10
# 14    -         0.000000    0    0     0               4                 0
# 15    -         0.000000    0    0     0               0                 4
# 16    -         0.000000    0    0     0               0                 0
# 17    -         0.000000    0    0     0               0                 0
# 18    -         0.000000    0    0     0               0                 0
# 19    -         0.000000    0    0     0               0                 0
#
#     3_day_before_LOC  day_before_ORG  2_day_before_ORG  3_day_before_ORG  \
# 0                  0               0                 0                 0
# 1                  0               4                 0                 0
# 2                  0               0                 4                 0
# 3                  6               0                 0                 4
# 4                  2               0                 0                 0
# 5                  2               0                 0                 0
# 6                  0               1                 0                 0
# 7                  2               1                 1                 0
# 8                  4               0                 1                 1
# 9                  3               0                 0                 1
# 10                 0               0                 0                 0
# 11                 0               0                 0                 0
# 12                 0               2                 0                 0
# 13                 0               0                 2                 0
# 14                10               8                 0                 2
# 15                 0               0                 8                 0
# 16                 4               0                 0                 8
# 17                 0               0                 0                 0
# 18                 0               0                 0                 0
# 19                 0               0                 0                 0
#
#     day_before_PERS  2_day_before_PERS  3_day_before_PERS
# 0                 0                  0                  0
# 1                38                  0                  0
# 2                 0                 38                  0
# 3                 0                  0                 38
# 4                 0                  0                  0
# 5                 5                  0                  0
# 6                 3                  5                  0
# 7                 3                  3                  5
# 8                 0                  3                  3
# 9                 0                  0                  3
# 10                0                  0                  0
# 11                0                  0                  0
# 12               22                  0                  0
# 13                0                 22                  0
# 14               23                  0                 22
# 15                0                 23                  0
# 16                0                  0                 23
# 17                0                  0                  0
# 18                0                  0                  0
# 19                0                  0                  0

# %%
full_data.to_csv("ready_full_data.csv", encoding='utf-8')

# %%
import sys
# !{sys.executable} -m pip install sklearn
# Out:
# Requirement already satisfied: sklearn in /Users/tbatsenko/ml/lib/python3.7/site-packages (0.0)
# Requirement already satisfied: scikit-learn in /Users/tbatsenko/ml/lib/python3.7/site-packages (from sklearn) (0.21.1)
# Requirement already satisfied: joblib>=0.11 in /Users/tbatsenko/ml/lib/python3.7/site-packages (from scikit-learn->sklearn) (0.13.2)
# Requirement already satisfied: numpy>=1.11.0 in /Users/tbatsenko/ml/lib/python3.7/site-packages (from scikit-learn->sklearn) (1.16.3)
# Requirement already satisfied: scipy>=0.17.0 in /Users/tbatsenko/ml/lib/python3.7/site-packages (from scikit-learn->sklearn) (1.2.0)

# %%
from sklearn.model_selection import train_test_split



train_features, cv_images, train_labels, cv_labels = train_test_split(train_images, train_labels, test_size=0.2, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-201-98e233b14b4e> in <module>
#       1 from sklearn.model_selection import train_test_split
# ----> 2 train_images, cv_images, train_labels, cv_labels = train_test_split(train_images, train_labels, test_size=0.2, random_state=42)
#
# NameError: name 'train_images' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-202-3d17080fd2a9> in <module>
# ----> 1 from sklearn import metrics, cross_validation
#       2 from sklearn import linear_model
#
# ImportError: cannot import name 'cross_validation' from 'sklearn' (/Users/tbatsenko/ml/lib/python3.7/site-packages/sklearn/__init__.py)
